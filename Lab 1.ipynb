# %%
import random
import matplotlib.pyplot as plt

twoDigitCollision = []

for i in range(200):
    
    notFound = True

    # Make a new array of size 100 and fill it with 0
    digitList = [0]*100

    # Keep track of how many runs until a collision
    count = 0

    # While we have no collision keep trying
    while notFound:
        studentId = random.randint(999999,10000000)

        count += 1

        # Extract the last 2 digits of the studentId
        lastTwo = studentId % 100

        # If the index has already been generated, we have a collision
        if digitList[lastTwo] == 1:
            notFound = False
        # Otherwise, indicate that this index has been generated
        else:
            digitList[lastTwo] = 1

    # Printing the number of attempts it took
    #print(count)
    
    # Adding the data to a list to plot it later
    twoDigitCollision.append(count)
    
# scatter plot

plt.scatter(range(200), twoDigitCollision)

# add title
plt.title("2 Digit Scatter Plot")
 
# set X and Y labels
plt.xlabel('Trial')
plt.ylabel('Attempts before Collision')
 
plt.show()

# %%
import random
import matplotlib.pyplot as plt

threeDigitCollision = []

for i in range(200):
    
    notFound = True

    # Make a new array of size 100 and fill it with 0
    digitList = [0]*1000

    # Keep track of how many runs until a collision
    count = 0

    # While we have no collision keep trying
    while notFound:
        studentId = random.randint(999999,10000000)

        count += 1

        # Extract the last 2 digits of the studentId
        lastTwo = studentId % 1000

        # If the index has already been generated, we have a collision
        if digitList[lastTwo] == 1:
            notFound = False
        # Otherwise, indicate that this index has been generated
        else:
            digitList[lastTwo] = 1

    # Printing the number of attempts it took
    #print(count)
    
    # Adding the data to a list to plot it later
    threeDigitCollision.append(count)

# scatter plot

plt.scatter(range(200), threeDigitCollision)

# add title
plt.title("3 Digit Scatter Plot")
 
# set X and Y labels
plt.xlabel('Trial')
plt.ylabel('Attempts before Collision')
 
plt.show()

# %%
import random
import matplotlib.pyplot as plt

fourDigitCollision = []

for i in range(200):
    
    notFound = True

    # Make a new array of size 100 and fill it with 0
    digitList = [0]*10000

    # Keep track of how many runs until a collision
    count = 0

    # While we have no collision keep trying
    while notFound:
        studentId = random.randint(999999,10000000)

        count += 1

        # Extract the last 2 digits of the studentId
        lastTwo = studentId % 10000

        # If the index has already been generated, we have a collision
        if digitList[lastTwo] == 1:
            notFound = False
        # Otherwise, indicate that this index has been generated
        else:
            digitList[lastTwo] = 1

    # Printing the number of attempts it took
    #print(count)
    
    # Adding the data to a list to plot it later
    fourDigitCollision.append(count)

# scatter plot

plt.scatter(range(200), fourDigitCollision)

# add title
plt.title("4 Digit Scatter Plot")
 
# set X and Y labels
plt.xlabel('Trial')
plt.ylabel('Attempts before Collision')
 
plt.show()

# %%
data = [twoDigitCollision, threeDigitCollision, fourDigitCollision]

# Making a plot
plt.boxplot(data) 

# display the plot
plt.show()

# %%
print("The average collisions for the last 2 digits is", sum(twoDigitCollision)/len(twoDigitCollision))
print("The average collisions for the last 3 digits is", sum(threeDigitCollision)/len(threeDigitCollision))
print("The average collisions for the last 4 digits is", sum(fourDigitCollision)/len(fourDigitCollision))
# Out:
# The average collisions for the last 2 digits is 12.55
# The average collisions for the last 3 digits is 41.535
# The average collisions for the last 4 digits is 124.05

# %%
import matplotlib.pyplot as plt
plt.scatter(range(200), twoDigitCollision)
plt.scatter(range(200), threeDigitCollision)
plt.scatter(range(200), fourDigitCollision)

# add title
plt.title("Scatter Plot of Every Digit")
 
# set X and Y labels
plt.xlabel('Trial')
plt.ylabel('Attempts before Collision')

plt.legend(['2 Digits','3 Digits','4 Digits'])

plt.show()
